# %%
# %sql
Lazy evalution:
    Transformation
        1. read
        2. Filter
 
 
    Action.
        1.show or display
        2.count
        3.write

# %%
# %sql
reader api
df=spark.read.file_format("path")
 
writer api
df.write.file_format("path")
 
source(csv) --- target(tables)

# %%
df_finance=spark.read.csv("/Volumes/kj_dev/default/csv_files/financial_dataset.csv")

# %%
df_finance=spark.read.csv("/Volumes/kj_dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)

# %%
#df_finance.show()
df_finance.display()
#df_finance.count()

# %%
df_finance.write.mode('overwrite').saveAsTable("kj_dev.default.finance_pyspark")

# %%
df_deposit=df_finance.filter("TransactionType='Deposit'")

# %%
df_finance=spark.read.csv("/Volumes/kj_dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)
df_finance.write.mode("overwrite").saveAsTable("kj_dev.default.finance_pyspark")

# %%
# %sql
select * from kj_dev.default.finance_pyspark
