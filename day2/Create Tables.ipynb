-- %% [markdown]
-- #ELT/ETL
--
-- ##Ways to create a table
-- ###1.SQL (csv, json,parquet,delta) medium size gb
-- ###2.Pyspark (csv, json,parquet,delta) large size (pb tb gb)
-- ###3.UI  (limitation - volume, simple datasets only

-- %%
create table kj_dev.default.financial as
select * from read_files("/Volumes/kj_dev/default/csv_files/financial_dataset.csv")

-- %%
select * from kj_dev.default.financial

-- %%
describe kj_dev.default.financial

-- %%
describe extended kj_dev.default.financial

-- %%
select * from csv.`/Volumes/kj_dev/default/csv_files/financial_dataset.csv`

-- %%
create table kj_dev.default.retail_orders
select * from read_files("/Volumes/kj_dev/default/csv_files/retail_orders.json")

-- %%
select * from kj_dev.default.retail_orders

-- %%
select * from
