# %%
df=spark.read.table("samples.tpch.customer")

# %%
df.count()

# %%
df1=df.select("c_custkey","c_name")

# %%
df.withColumnRenamed("c_custkey","custkey").withColumnRenamed("c_name","name")

# %%
df.withColumnsRenamed({"c_custkey":"custkey","c_name":"name"})

# %%
from pyspark.sql.functions import *

# %%
df_new=df.withColumn("ingestion_date",current_timestamp())

# %%
df_new.display()

# %%
withColumn--- new col or change in the existing.

# %%
df.withColumn("c_mktsegment", lower("c_mktsegment")).display()

# %%
df.withColumn("segment_new", lower("c_mktsegment")).display()

# %%
# %sql
select c_custkey as custkey, c_name from samples.tpch.customer
