-- %% [markdown]
-- ## Getting started with notebooks
-- ### With lakehouse
-- # this is for fonts

-- %% [markdown]
-- ## Creating Schema

-- %%
use catalog kj_dev;
create schema kj_dev.example;

-- %%
%python
print("Hello Python")

-- %%
%sql
select "Hello SQL"

-- %%
create table kj_dev.example.emp (id int primary key, name string)

-- %%
insert into kj_dev.example.emp values (1,'Naval'),(2,'Anil'),(3,'Sangram')

-- %%
select * from kj_dev.example.emp
